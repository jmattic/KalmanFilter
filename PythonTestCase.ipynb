# %%
import numpy as np
import filterpy
from filterpy.kalman import KalmanFilter as kf
from filterpy.kalman import predict, update
from numpy.random import randn
from filterpy.common import Q_discrete_white_noise
import matplotlib.pyplot as plt

# %%
testcase = 2 #Change value to 1 or 2 to test different data
printcase = 1 #To print data put 1

if testcase == 1:
    ztotal = np.array([0.,1,1,3,4]) #[1.,1,0,1,1]])
    ztrue = np.array([0.,1,2,3,4])
    x = np.array([[0.],
                  [1]]) #initial estimate and velocity
elif testcase == 2:
    ztrue = np.zeros(50)
    ztotal = np.zeros(50)
    for j in range(len(ztrue)-1):
        ztrue[j+1] = ztrue[j]+1.25*abs(randn())
        ztotal[j+1] = ztrue[j+1]+2*randn()
    x = np.array([[0.],
                  [1.2]]) #initial estimate and velocity
else:
    print("Variable testcase was not a correct value. Can only be 1 or 2.")
    raise ValueError

n_iter = len(ztotal)
dt = 1. #Time passing between each iteration
#print(n_iter)
x1 = np.zeros(n_iter)
x2 = np.zeros(n_iter)
Pminus = np.zeros(n_iter)
xhat = np.zeros(n_iter)
#print(x2)

# %%
f = kf(dim_x=2, dim_z = 1) #Estimating two variables but only taking in one measurement
f.x = x #Estimate
#f.z = z
f.F = np.array([[1,dt],
                [0,1]]) #State Transition Matrix, eqns related to variables
f.P = np.diag([225,49.]) #State Covariance, relation between variables
f.R = 50 #Measurement noise/covariance
f.H = np.array([[1.,0]]) #Measurement function
f.Q = Q_discrete_white_noise(dim=2, dt=dt, var=0.1) #Process noise/covariance

# %%
def getmeasurement(i):
    z_current = np.zeros(1)
    z_current[0] = ztotal[i]
    #z_current[1,0] = ztotal[1,i]
    return z_current

def plotstuff():
    plt.figure()
    plt.plot(ztotal,'k+',label='Noisy Measurements')
    plt.plot(x1,'b-',label='A Posteri Estimate')
    plt.plot(ztrue,color='g',label='True Value')
    plt.plot(xhat,'r*',label='Prediction')
    plt.legend()
    plt.title('Estimate vs. Iteration Step', fontweight='bold')
    plt.xlabel('Iteration')
    plt.ylabel('Position')
    
    plt.figure()
    valid_iter = range(1,n_iter) # Pminus not valid at step 0
    plt.plot(valid_iter,Pminus[valid_iter],label='A Priori Error Estimate')
    plt.title('Estimated $\it{\mathbf{a \ priori}}$ Error vs. Iteration Step', fontweight='bold')
    plt.xlabel('Iteration')
    plt.ylabel('$(Position)^2$')
    #plt.setp(plt.gca(),'ylim',[0,.01])
    plt.show()

counter = 0
while True:
    z = getmeasurement(counter)
    f.z = z #Worked without this, do I need it?
    f.predict()
    xjay = f.x
    xhat[counter] = xjay[0,0]
    #print(x)
    f.update(z)
    x = f.x
    x1[counter] = x[0,0]
    #x2[counter] = x[1,0]
    Pminus[counter] = f.P[0,0]
    #np.insert(x1,counter,x[0,0])
    #np.insert(x2,counter,x[1,0])
    #print(x)
    if printcase == 1:
        print("Iteration:", counter)
        print("Estimated Position:", x[0,0])
        print("True Position:", ztrue[counter])
        #print("Estimated Velocity:", x[1,0])
    counter += 1
    if (counter == (n_iter)):
        break
#print(x1)
plotstuff()
# Out:
# Iteration: 0
# Estimated Position: 0.18517089730730674
# True Position: 0.0
# Estimated Velocity: 1.0183473497415323
# Iteration: 1
# Estimated Position: 2.0914856659844427
# True Position: 2.0150601982884804
# Estimated Velocity: 1.4599365120857437
# Iteration: 2
# Estimated Position: 1.4878186117890873
# True Position: 3.500318903798283
# Estimated Velocity: 0.5144566914297841
# Iteration: 3
# Estimated Position: 2.668622258441082
# True Position: 3.7498757540871765
# Estimated Velocity: 0.7625701909507028
# Iteration: 4
# Estimated Position: 3.8392118406348685
# True Position: 3.9087768149560773
# Estimated Velocity: 0.887520964115662
# Iteration: 5
# Estimated Position: 4.4552680857396
# True Position: 3.9242841762460694
# Estimated Velocity: 0.8171900720127075
# Iteration: 6
# Estimated Position: 5.7274273424101105
# True Position: 5.764678512279877
# Estimated Velocity: 0.9196711551581452
# Iteration: 7
# Estimated Position: 6.522207445700753
# True Position: 7.591509592900684
# Estimated Velocity: 0.8946072322843404
# Iteration: 8
# Estimated Position: 9.166329335815727
# True Position: 9.475618508533662
# Estimated Velocity: 1.2143910150690802
# Iteration: 9
# Estimated Position: 10.49808194232593
# True Position: 10.472555650574119
# Estimated Velocity: 1.2343234562414294
# Iteration: 10
# Estimated Position: 11.909557246137298
# True Position: 11.068449580359328
# Estimated Velocity: 1.262786866018364
# Iteration: 11
# Estimated Position: 14.100233569459713
# True Position: 12.17924644572706
# Estimated Velocity: 1.4060731230353132
# Iteration: 12
# Estimated Position: 14.903126563765468
# True Position: 12.36272710032279
# Estimated Velocity: 1.315352618152942
# Iteration: 13
# Estimated Position: 15.319610475692798
# True Position: 13.27996615304699
# Estimated Velocity: 1.1822702580416187
# Iteration: 14
# Estimated Position: 15.64574085334242
# True Position: 14.322926599233844
# Estimated Velocity: 1.056499888136495
# Iteration: 15
# Estimated Position: 16.442610327489263
# True Position: 14.728724865555845
# Estimated Velocity: 1.0184491978917976
# Iteration: 16
# Estimated Position: 16.65398959753152
# True Position: 15.926321622789436
# Estimated Velocity: 0.900051041510478
# Iteration: 17
# Estimated Position: 18.454534737987146
# True Position: 18.089690049446787
# Estimated Velocity: 1.0325134418138833
# Iteration: 18
# Estimated Position: 19.001388365818958
# True Position: 18.351422662945282
# Estimated Velocity: 0.9608362869276158
# Iteration: 19
# Estimated Position: 20.4672286998261
# True Position: 19.002153850984882
# Estimated Velocity: 1.0356069293225478
# Iteration: 20
# Estimated Position: 20.92867908419612
# True Position: 19.620966403775046
# Estimated Velocity: 0.9503672942001483
# Iteration: 21
# Estimated Position: 21.600237130993314
# True Position: 20.761880523617265
# Estimated Velocity: 0.9088891319113611
# Iteration: 22
# Estimated Position: 21.8198133368426
# True Position: 20.782147965059046
# Estimated Velocity: 0.8061918140441962
# Iteration: 23
# Estimated Position: 23.046653446742543
# True Position: 22.3207201296143
# Estimated Velocity: 0.868919537229666
# Iteration: 24
# Estimated Position: 24.585085977760357
# True Position: 23.661649747677767
# Estimated Velocity: 0.9688082650904335
# Iteration: 25
# Estimated Position: 24.851336253014694
# True Position: 24.078731483052067
# Estimated Velocity: 0.8639678535376717
# Iteration: 26
# Estimated Position: 25.539252884264886
# True Position: 24.58970595932127
# Estimated Velocity: 0.8376958892314016
# Iteration: 27
# Estimated Position: 25.659933501587723
# True Position: 24.73773821171005
# Estimated Velocity: 0.7307059676741674
# Iteration: 28
# Estimated Position: 26.60675295990876
# True Position: 26.120710727331694
# Estimated Velocity: 0.7629491010271103
# Iteration: 29
# Estimated Position: 27.73817419355565
# True Position: 27.02618956243389
# Estimated Velocity: 0.8179155588181344
# Iteration: 30
# Estimated Position: 28.4503181423126
# True Position: 28.29894786632837
# Estimated Velocity: 0.8021392096552342
# Iteration: 31
# Estimated Position: 29.23810794033717
# True Position: 29.649824199629375
# Estimated Velocity: 0.7999991454935896
# Iteration: 32
# Estimated Position: 29.205664621103338
# True Position: 29.669139894531785
# Estimated Velocity: 0.6758584321542229
# Iteration: 33
# Estimated Position: 30.442306250206176
# True Position: 29.969070067576297
# Estimated Velocity: 0.7594828803677417
# Iteration: 34
# Estimated Position: 31.795812917170174
# True Position: 31.416411204226986
# Estimated Velocity: 0.8480615779365164
# Iteration: 35
# Estimated Position: 31.897756830516904
# True Position: 32.21498279493116
# Estimated Velocity: 0.7368047759735283
# Iteration: 36
# Estimated Position: 32.376183061405975
# True Position: 32.316557358366474
# Estimated Velocity: 0.6982769981363144
# Iteration: 37
# Estimated Position: 32.877907715593146
# True Position: 32.79945426911069
# Estimated Velocity: 0.6689682887732886
# Iteration: 38
# Estimated Position: 33.429286982724435
# True Position: 32.868385112872154
# Estimated Velocity: 0.6514340241920767
# Iteration: 39
# Estimated Position: 33.25810593038931
# True Position: 34.76702141055916
# Estimated Velocity: 0.5287691559196704
# Iteration: 40
# Estimated Position: 34.963794666371875
# True Position: 37.19980962590153
# Estimated Velocity: 0.7042674716774272
# Iteration: 41
# Estimated Position: 36.46637690431201
# True Position: 39.76971014284517
# Estimated Velocity: 0.8233101105275533
# Iteration: 42
# Estimated Position: 38.48297016038358
# True Position: 41.04145163715213
# Estimated Velocity: 1.00125011051963
# Iteration: 43
# Estimated Position: 40.78881236954599
# True Position: 41.642497926987716
# Estimated Velocity: 1.1957888102705605
# Iteration: 44
# Estimated Position: 43.07152243765265
# True Position: 45.12679764576502
# Estimated Velocity: 1.357869059110575
# Iteration: 45
# Estimated Position: 44.35564356010047
# True Position: 46.81967405390628
# Estimated Velocity: 1.3468718548059986
# Iteration: 46
# Estimated Position: 45.37606659176806
# True Position: 46.98455251791019
# Estimated Velocity: 1.2981921772143878
# Iteration: 47
# Estimated Position: 47.266099043054936
# True Position: 48.588076595336304
# Estimated Velocity: 1.3864467289083924
# Iteration: 48
# Estimated Position: 48.35498923227893
# True Position: 50.05430144447402
# Estimated Velocity: 1.3420754421305012
# Iteration: 49
# Estimated Position: 49.960112951348655
# True Position: 51.25772559710127
# Estimated Velocity: 1.3813008866162886
